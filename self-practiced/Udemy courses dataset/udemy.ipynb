# %% [markdown]
# Udemy Courses Dataset
# Reuirements:
# -What are the different subjects/courses udemy offers?
# -Find out the maximum number of courses each category has?
# -Show all the courses which are free  of cost.
# -Show all courses which are paid.
# -Which are the top selling courses?
# -Which are the least selling courses
# -Show all the courses of graphic design, where the prices are below 100.
# -Find out all the courses which are related to python.
# -Courses published in 2017.
# -What are the maximum number of subscribers for each level of courses.

# %%
import pandas as pd

# %%
udemy=pd.read_csv("udemy_courses.csv")
udemy.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udemy.shape
# Out:
# (3678, 12)

# %%
udemy.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
#q2
udemy.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
#q3 false means free, true means paid
udemy.is_paid == False
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Name: is_paid, Length: 3678, dtype: bool

# %%
#if you want to see the data in dataframe
udemy[udemy.is_paid == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
udemy[udemy.is_paid == False].shape
# Out:
# (310, 12)

# %%
udemy[udemy.is_paid == True]
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemy[udemy.is_paid == True].shape
# Out:
# (3368, 12)

# %%
#q5
udemy.sort_values('num_subscribers',ascending=False)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1621     995384  Professional Business Logo Design Using Free O...
# 785     1233302            Ratio Analysis for Financial Statements
# 784     1271182  Practical Film Financing: Finding & Pitching I...
# 1471     188584                        Letras en Adobe Illustrator
# 1472     181268               Photoshop: Creando elemental de aire
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %%
#q6
udemy.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  \
# 777     1215926                Kickstarter success in 5 easy steps
# 781      975910             How to achieve personal transformation
# 779     1249146  Planning and Executing a Financial Statement A...
# 778     1035638                 Understanding Financial Statements
# 1569     726314       Create Beautiful Image Maps for Your Website
# ...         ...                                                ...
# 3232     764164              The Complete Web Developer Course 2.0
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3230     625204                         The Web Developer Bootcamp
# 3032      59014                     Coding for Entrepreneurs Basic
# 2827      41295               Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 777   https://www.udemy.com/kickstarter-success-in-5...     True     20
# ...

# %%
#q7
udemy.subject == 'Graphic Design'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Name: subject, Length: 3678, dtype: bool

# %%
udemy[udemy.subject == 'Graphic Design']
# Out:
#       course_id                                       course_title  \
# 1195     880202           Anatomy and Figure Drawing for Beginners
# 1196    1197206                         Illustrator CC MasterClass
# 1197    1117796  Typographic Logo Design in Illustrator - Begin...
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1199     595876  Logo Design in Adobe Illustrator - for Beginne...
# ...         ...                                                ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop
# 1795     496430  Infographic Design: How To Create Your Own Inf...
# 1796     793246           Autodesk Inventor 2016 : Complete Guide
# 1797     547190               Amazing Graphic Design for Beginners
#
#                                                     url  is_paid  price  \
# 1195  https://www.udemy.com/anatomy-and-figure-drawi...     True    150
# ...

# %%
udemy[(udemy.subject == 'Graphic Design')&(udemy.price < 100)]
# Out:
#       course_id                                       course_title  \
# 1196    1197206                         Illustrator CC MasterClass
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1202      28556              Discover How to Draw and paint Comics
# 1203     317278  Typographic Logos: Typography and Lettering fo...
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...
# ...         ...                                                ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop
# 1795     496430  Infographic Design: How To Create Your Own Inf...
# 1796     793246           Autodesk Inventor 2016 : Complete Guide
# 1797     547190               Amazing Graphic Design for Beginners
#
#                                                     url  is_paid  price  \
# 1196  https://www.udemy.com/illustrator-cc-masterclass/     True     95
# ...

# %%
udemy[(udemy.subject == 'Graphic Design')&(udemy.price == 100)]
# Out:
#       course_id                                       course_title  \
# 1248    1160004                 Design a logo for FREE in Inkscape
# 1288     927186        Learn Blender 3D  - The introduction course
# 1338     638040  Adobe Photoshop Essentials: Master Adobe Photo...
# 1347    1246168  Illustrator para criação de peças gráficas, De...
# 1376     654038              How To Sell Your Art Online With ETSY
# 1380    1243016        Photoshop - Tratamento de pele profissional
# 1381    1266468  Indesign - Para quem quer trabalhar com Design...
# 1417     978462              Blender Modelling Series - Volume Two
# 1452    1027080              Logo Portfolio in 1 Hour in Wordpress
# 1489     482924  Mastering Retouching and Restoration (15 proje...
# 1507    1161864  Diseño impreso - Preimpresión para offset en I...
# 1540     490392                Getting Started with Illustrator CC
# 1577    1012262     Icon & Logo Symbol Design in Adobe Illustrator
# ...

# %%
#q8
udemy[udemy.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
udemy[udemy.course_title.str.contains('Python')].shape
# Out:
# (29, 12)

# %%
len(udemy[udemy.course_title.str.contains('Python')])
# Out:
# 29

# %%
#q9
udemy.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
#to convert date time function(published_timestamp column)
udemy['published_timestamp']=pd.to_datetime(udemy.published_timestamp)

# %%
udemy.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance
# 1 2017-03-09 16:34:20+00:00  Business Finance

# %%
#to add new column which shows only year( try month or date as well)
udemy['Year']=udemy['published_timestamp'].dt.year

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017
# 1 2017-03-09 16:34:20+00:00  Business Finance  2017

# %%
#to check 2017 published courses or different years
udemy[udemy.Year==2017]
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 9       1167710  The Only Investment Strategy You Need For Your...
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# ...         ...                                                ...
# 3651    1079078                             Drupal 8 Site Building
# 3652     919354  Learn Bootstrap 4 The Most Popular HTML5 CSS3 ...
# 3653    1248172            Essentials of Spring 5.0 for Developers
# 3664    1115064               XML DTD - Crash Course for Beginners
# 3674    1088178  How To Design A WordPress Website With No Codi...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
#to check shape
udemy[udemy.Year==2017].shape
# Out:
# (715, 13)

# %%
#to check length function
len(udemy[udemy.Year==2017])
# Out:
# 715

# %%
#q10
udemy.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
udemy.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
udemy.groupby('level')['num_subscribers'].min()
# Out:
# level
# All Levels            0
# Beginner Level        0
# Expert Level          1
# Intermediate Level    0
# Name: num_subscribers, dtype: int64

# %%
udemy.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                                                                   url  \
# level
# All Levels          https://www.udemy.com/zombie-apocalypse-photos...
# Beginner Level                        https://www.udemy.com/zprzqgfl/
# Expert Level        https://www.udemy.com/working-capital-manageme...
# Intermediate Level           https://www.udemy.com/youtubedownloader/
#
#                     is_paid  price  num_subscribers  num_reviews  \
# level
# ...
