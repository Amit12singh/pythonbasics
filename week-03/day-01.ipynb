# %% [markdown]
# Bar Plot

# %%
import matplotlib.pyplot as plt
x=["python","c","c++","Java"]
y=[85,70,60,82]
z=[20,30,40,50]
plt.xlabel("language", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.title("bar plot",fontsize=15)
c=["y","b","m","g"]
plt.bar(x,y, width=0.4, color=c, align="center", edgecolor="r", linewidth=5, linestyle=":", alpha=0.5, label="popularity")
plt.bar(x,z,width=0.4,color="r",label="popularity1")
plt.legend()
plt.show()

# %%
import numpy as np

x=["python","c","c++","Java"]
y=[85,70,60,82]
z=[20,30,40,50]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.title("bar plot",fontsize=15)

plt.bar(p,y, width, color="r",label="popularity")
plt.bar(p1,z,width,color="y",label="popularity1")

plt.xticks(p+width/2,x, rotation=20)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","c","c++","Java"]
y=[85,70,60,82]
z=[20,30,40,50]

plt.xlabel("language", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.title("bar plot",fontsize=15)

plt.barh(x,y, color="r", align="center", edgecolor="r", linewidth=5, linestyle=":", alpha=0.5, label="popularity")
plt.barh(x,z,color="y",label="popularity1")
plt.legend()
plt.show()

# %% [markdown]
# Scatter Plot

# %%
day=[1,2,3,4,5,6,7]
no=[2,3,1,4,5,3,6]
plt.scatter(day,no,color="r")
plt.title("Scatter Plot", fontsize=15)
plt.xlabel("Day", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day=[1,2,3,4,5,6,7]
no=[2,3,1,4,5,3,6]
colors=["r","y","g","b","r","g","r"]
sizes=[100,200,400,200,100,700,500]
plt.scatter(day,no,c=colors,s=sizes,alpha=0.5,marker="*", edgecolor="g", linewidth=2)
plt.title("Scatter Plot", fontsize=15)
plt.xlabel("Day", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day=[1,2,3,4,5,6,7]
no=[2,3,1,4,5,3,6]
colors=[10,49,30,29,56,20,30]
sizes=[100,200,400,200,100,700,500]
plt.scatter(day,no,c=colors,s=sizes,cmap="viridis", alpha=0.4)
t=plt.colorbar()
t.set_label("ColorBar",fontsize=15)
plt.title("Scatter Plot", fontsize=15)
plt.xlabel("Day", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day=[1,2,3,4,5,6,7]
no=[2,3,1,4,5,3,6]
no2=[3,2,4,5,1,6,2]
colors=[10,49,30,29,56,20,30]
sizes=[100,200,400,200,100,700,500]
plt.scatter(day,no,c=colors,s=sizes,cmap="viridis", alpha=0.5)
plt.scatter(day,no2,c=colors,s=sizes, alpha=0.5)
t=plt.colorbar()
t.set_label("ColorBar",fontsize=15)
plt.title("Scatter Plot", fontsize=15)
plt.xlabel("Day", fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %% [markdown]
# Pie Plot

# %%
x=[10,20,30,40]
y=["c","c++","Java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","b","g","y"]

plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1.3,labeldistance=1.1,startangle=90,
        textprops={"fontsize":15},counterclock=False,wedgeprops={"linewidth":5},rotatelabels=True)

plt.title("Pie Chart")
plt.legend(loc=2)
plt.show()

# %%
plt.pie([1])
plt.show()

# %%
x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","Java","python"]

c=["r","b","g","y"]

plt.pie(x,labels=y,radius=1.5)
plt.pie([1],colors="w")


plt.show()

# %%
x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","Java","python"]

c=["r","b","g","y"]

plt.pie(x,labels=y,radius=1.5)
cr=plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca().add_artist(cr)

plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
mart=pd.read_excel("supermarket_sales.xlsx")
mart.shape
# Out:
# (1000, 17)

# %%
mart.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
sns.countplot(x='Gender',data=mart)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product line", data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
sns.countplot(y="Product line", data=mart)
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product line",hue="Gender", data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product line",hue="Gender", data=mart,palette="gist_gray")
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
sns.get_dataset_names()
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
mart = pd.read_excel("supermarket_sales.xlsx")
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Total',y='Product line',data=mart)
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
x=mart['Product line'].sort_values()
x.unique()
# Out:
# array(['Electronic_accessories', 'Fashion_accessories',
#        'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
#        'Sports_and_travel'], dtype=object)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart, order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'],hue_order=['Male','Female'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart, order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'],hue_order=['Male','Female'],color='red')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart, order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'],palette='cividis')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart, order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'],palette='cividis',saturation=5)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart, order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'],palette='cividis',
       estimator=sum)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart, order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'],palette='cividis',
       estimator=np.median)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
