# %%
import pandas as pd
covid_19= pd.read_csv("covid_19_data.csv")
covid_19
# Out:
#        SNo ObservationDate                        Province/State  \
# 0        1      01/22/2020                                 Anhui
# 1        2      01/22/2020                               Beijing
# 2        3      01/22/2020                             Chongqing
# 3        4      01/22/2020                                Fujian
# 4        5      01/22/2020                                 Gansu
# ...    ...             ...                                   ...
# 4242  4243      03/08/2020                    Northern Territory
# 4243  4244      03/08/2020  Lackland, TX (From Diamond Princess)
# 4244  4245      03/08/2020                 Montgomery County, TX
# 4245  4246      03/08/2020     Omaha, NE (From Diamond Princess)
# 4246  4247      03/08/2020    Travis, CA (From Diamond Princess)
#
#       Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0     Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
covid_19.shape
# Out:
# (4247, 8)

# %%
#shows not null values in dataset, null values means missing values
covid_19.count()
# Out:
# SNo                4247
# ObservationDate    4247
# Province/State     2746
# Country/Region     4247
# Last Update        4247
# Confirmed          4247
# Deaths             4247
# Recovered          4247
# dtype: int64

# %%
#shows result in Boolean
covid_19.isnull()
# Out:
#         SNo  ObservationDate  Province/State  Country/Region  Last Update  \
# 0     False            False           False           False        False
# 1     False            False           False           False        False
# 2     False            False           False           False        False
# 3     False            False           False           False        False
# 4     False            False           False           False        False
# ...     ...              ...             ...             ...          ...
# 4242  False            False           False           False        False
# 4243  False            False           False           False        False
# 4244  False            False           False           False        False
# 4245  False            False           False           False        False
# 4246  False            False           False           False        False
#
#       Confirmed  Deaths  Recovered
# 0         False   False      False
# ...

# %%
#shows null values total in each column
covid_19.isnull().sum()
# Out:
# SNo                   0
# ObservationDate       0
# Province/State     1501
# Country/Region        0
# Last Update           0
# Confirmed             0
# Deaths                0
# Recovered             0
# dtype: int64

# %%
#for visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid_19.isnull())
plt.show()

# %% [markdown]
# Q1. Show the number of confirmed, deaths and recovered cases in each region.
# each , use groupby function.

# %%
covid_19.head(3)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0

# %%
#each, use groupby function
covid_19.groupby('Country/Region').sum()
# Out:
#                           SNo  \
# Country/Region
#  Azerbaijan              2664
# Afghanistan             42823
# Algeria                 40233
# Andorra                 24901
# Argentina               21692
# ...                       ...
# US                    2131972
# Ukraine                 22172
# United Arab Emirates    73821
# Vatican City            11989
# Vietnam                 74949
#
#                                                         ObservationDate  \
# Country/Region
#  Azerbaijan                                                  02/28/2020
# Afghanistan           02/24/202002/25/202002/26/202002/27/202002/28/...
# Algeria               02/25/202002/26/202002/27/202002/28/202002/29/...
# Andorra               03/02/202003/03/202003/04/202003/05/202003/06/...
# Argentina             03/03/202003/04/202003/05/202003/06/202003/07/...
# ...                                                                 ...
# ...

# %%
covid_19.groupby('Country/Region').sum().head(25)
# Out:
#                            SNo  \
# Country/Region
#  Azerbaijan               2664
# Afghanistan              42823
# Algeria                  40233
# Andorra                  24901
# Argentina                21692
# Armenia                  27824
# Australia               420073
# Austria                  39935
# Azerbaijan               27500
# Bahrain                  42046
# Bangladesh                4127
# Belarus                  33030
# Belgium                  71216
# Bhutan                   11804
# Bosnia and Herzegovina   15200
# Brazil                   38032
# Bulgaria                  4117
# Cambodia                 75545
# Cameroon                 11782
# Canada                  274236
# Chile                    21686
# Colombia                 11902
# Costa Rica               11755
# Croatia                  40154
# Czech Republic           27397
#
#                                                           ObservationDate  \
# Country/Region
# ...

# %%
#only confirmed cases. Column names are case sensitive
covid_19.groupby('Country/Region')['Confirmed'].sum()
# Out:
# Country/Region
#  Azerbaijan                1.0
# Afghanistan               17.0
# Algeria                   91.0
# Andorra                    7.0
# Argentina                 25.0
#                          ...
# US                      2660.0
# Ukraine                    6.0
# United Arab Emirates     524.0
# Vatican City               3.0
# Vietnam                  560.0
# Name: Confirmed, Length: 111, dtype: float64

# %% [markdown]
# #(ascending=false) and (ascending=True), use F and T capital
# Q2. In which Region maximum number of confirmed cases were recorded?
# Q3. In which Region minimum number of deaths were recorded?
# Q4. How many confirmed, death and recovered cases reported for Nepal till April 29, 2020?

# %%
covid_19.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Country/Region
# Mainland China    2312052.0
# South Korea         58078.0
# Italy               35041.0
# Iran                30003.0
# Others              15692.0
#                     ...
#  Azerbaijan             1.0
# Paraguay                1.0
# North Ireland           1.0
# Moldova                 1.0
# Ivory Coast             1.0
# Name: Confirmed, Length: 111, dtype: float64

# %%
covid_19.groupby('Country/Region').Deaths.sum().sort_values(ascending=True).head(50)
# Out:
# Country/Region
#  Azerbaijan               0.0
# Afghanistan               0.0
# Algeria                   0.0
# Andorra                   0.0
# Armenia                   0.0
# Austria                   0.0
# Bahrain                   0.0
# Azerbaijan                0.0
# Belgium                   0.0
# Bhutan                    0.0
# Bangladesh                0.0
# Belarus                   0.0
# Bosnia and Herzegovina    0.0
# Brazil                    0.0
# Cambodia                  0.0
# Bulgaria                  0.0
# Czech Republic            0.0
# Denmark                   0.0
# Cameroon                  0.0
# Canada                    0.0
# Chile                     0.0
# Colombia                  0.0
# Costa Rica                0.0
# Croatia                   0.0
# Estonia                   0.0
# Faroe Islands             0.0
# Dominican Republic        0.0
# Ecuador                   0.0
# Finland                   0.0
# Germany                   0.0
# ...

# %%
covid_19[covid_19['Country/Region'] == 'Nepal']
# Out:
#        SNo ObservationDate Province/State Country/Region          Last Update  \
# 167    168      01/25/2020            NaN          Nepal        1/25/20 17:00
# 213    214      01/26/2020            NaN          Nepal        1/26/20 16:00
# 259    260      01/27/2020            NaN          Nepal        1/27/20 23:59
# 310    311      01/28/2020            NaN          Nepal        1/28/20 23:00
# 362    363      01/29/2020            NaN          Nepal        1/29/20 19:30
# 417    418      01/30/2020            NaN          Nepal        1/30/20 16:00
# 485    486      01/31/2020            NaN          Nepal      1/31/2020 23:59
# 549    550      02/01/2020            NaN          Nepal       1/31/2020 8:15
# 617    618      02/02/2020            NaN          Nepal  2020-01-31T08:15:53
# 686    687      02/03/2020            NaN          Nepal  2020-01-31T08:15:53
# 756    757      02/04/2020            NaN          Nepal  2020-01-31T08:15:53
# ...

# %%
#top 10 records
covid_19.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Country/Region
# Mainland China    2312052.0
# South Korea         58078.0
# Italy               35041.0
# Iran                30003.0
# Others              15692.0
# Japan                5309.0
# France               4411.0
# Germany              4316.0
# Singapore            2817.0
# US                   2660.0
# Name: Confirmed, dtype: float64

# %%
covid_19.groupby('Country/Region')[['Confirmed','Deaths']].sum()
# Out:
#                       Confirmed  Deaths
# Country/Region
#  Azerbaijan                 1.0     0.0
# Afghanistan                17.0     0.0
# Algeria                    91.0     0.0
# Andorra                     7.0     0.0
# Argentina                  25.0     1.0
# ...                         ...     ...
# US                       2660.0    90.0
# Ukraine                     6.0     0.0
# United Arab Emirates      524.0     0.0
# Vatican City                3.0     0.0
# Vietnam                   560.0     0.0
#
# [111 rows x 2 columns]

# %% [markdown]
# Q5. Remove all the records where confirmed cases are less than 10

# %%
covid_19.head(3)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0

# %%
covid_19.Confirmed < 10
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 4242     True
# 4243     True
# 4244     True
# 4245     True
# 4246     True
# Name: Confirmed, Length: 4247, dtype: bool

# %%
#display result in dataframe
covid_19[covid_19.Confirmed < 10]
# Out:
#        SNo ObservationDate                        Province/State  \
# 0        1      01/22/2020                                 Anhui
# 2        3      01/22/2020                             Chongqing
# 3        4      01/22/2020                                Fujian
# 4        5      01/22/2020                                 Gansu
# 6        7      01/22/2020                               Guangxi
# ...    ...             ...                                   ...
# 4242  4243      03/08/2020                    Northern Territory
# 4243  4244      03/08/2020  Lackland, TX (From Diamond Princess)
# 4244  4245      03/08/2020                 Montgomery County, TX
# 4245  4246      03/08/2020     Omaha, NE (From Diamond Princess)
# 4246  4247      03/08/2020    Travis, CA (From Diamond Princess)
#
#       Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0     Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
covid_19[covid_19['Confirmed'] >= 10]
# Out:
#        SNo ObservationDate Province/State  Country/Region  \
# 1        2      01/22/2020        Beijing  Mainland China
# 5        6      01/22/2020      Guangdong  Mainland China
# 13      14      01/22/2020          Hubei  Mainland China
# 34      35      01/22/2020       Zhejiang  Mainland China
# 39      40      01/23/2020        Beijing  Mainland China
# ...    ...             ...            ...             ...
# 4086  4087      03/08/2020            NaN          Poland
# 4087  4088      03/08/2020            NaN    Saudi Arabia
# 4088  4089      03/08/2020            NaN         Estonia
# 4089  4090      03/08/2020          Macau           Macau
# 4090  4091      03/08/2020            NaN     Philippines
#
#               Last Update  Confirmed  Deaths  Recovered
# 1         1/22/2020 17:00       14.0     0.0        0.0
# 5         1/22/2020 17:00       26.0     0.0        0.0
# 13        1/22/2020 17:00      444.0    17.0       28.0
# ...

# %%
#to check, but data is still there
covid_19
# Out:
#        SNo ObservationDate                        Province/State  \
# 0        1      01/22/2020                                 Anhui
# 1        2      01/22/2020                               Beijing
# 2        3      01/22/2020                             Chongqing
# 3        4      01/22/2020                                Fujian
# 4        5      01/22/2020                                 Gansu
# ...    ...             ...                                   ...
# 4242  4243      03/08/2020                    Northern Territory
# 4243  4244      03/08/2020  Lackland, TX (From Diamond Princess)
# 4244  4245      03/08/2020                 Montgomery County, TX
# 4245  4246      03/08/2020     Omaha, NE (From Diamond Princess)
# 4246  4247      03/08/2020    Travis, CA (From Diamond Princess)
#
#       Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0     Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
#to remove permanently
covid_19 = covid_19[covid_19['Confirmed'] >= 10]

# %%
#to  check again
covid_19
# Out:
#        SNo ObservationDate Province/State  Country/Region  \
# 1        2      01/22/2020        Beijing  Mainland China
# 5        6      01/22/2020      Guangdong  Mainland China
# 13      14      01/22/2020          Hubei  Mainland China
# 34      35      01/22/2020       Zhejiang  Mainland China
# 39      40      01/23/2020        Beijing  Mainland China
# ...    ...             ...            ...             ...
# 4086  4087      03/08/2020            NaN          Poland
# 4087  4088      03/08/2020            NaN    Saudi Arabia
# 4088  4089      03/08/2020            NaN         Estonia
# 4089  4090      03/08/2020          Macau           Macau
# 4090  4091      03/08/2020            NaN     Philippines
#
#               Last Update  Confirmed  Deaths  Recovered
# 1         1/22/2020 17:00       14.0     0.0        0.0
# 5         1/22/2020 17:00       26.0     0.0        0.0
# 13        1/22/2020 17:00      444.0    17.0       28.0
# ...
